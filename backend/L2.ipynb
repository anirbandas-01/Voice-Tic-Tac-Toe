# %% [markdown]
# # L2: Voice & Generative UI in your App
#
# In this lesson, you'll run a real-time Voice AI agent that drives an interactive Tic-Tac-Toe Generative UI directly inside your browser and notebook using **Groq** (Llama 3.3 70B) or **OpenAI**.
#
# **Features:**
# - 🎙️ **Voice In & Speech Out** — Speak your moves ('Center', 'Top Left') or click the board.
# - 🤖 **Real-time AI Agent** — Generates strategic moves and spoken commentary.
# - ⚡ **Powered by Groq / OpenAI** — Uses tool calling (`place_mark`) for UI synchronization.

# %% [markdown]
# ## Step 1 — Setup & Environment Check

# %%
import os
from helpers import load_env, get_api_key, voice_widget

load_env()
groq_key = get_api_key('groq')
print('✓ Groq API Key loaded successfully!')

# %% [markdown]
# ## Step 2 — Render & Connect the Interactive Voice AI Widget
#
# Run the cell below to render the interactive Voice UI. Click **🎤 Start Voice**, allow microphone permission, and try:
#
# 1. Say **"Let's play tic-tac-toe."** or click a square.
# 2. Say **"Center"** or **"Top Left"** to make your move.
# 3. The AI agent will respond verbally and place its **O** mark on the board!

# %%
from IPython.display import HTML
# Render Voice AI widget powered by Groq Llama-3.3-70b
HTML(voice_widget(provider='groq'))
